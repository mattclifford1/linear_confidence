# %% [markdown]
# # Run the whole deltas algorithm

# %%
# %load_ext autoreload
# %autoreload 2

import ipywidgets
import deltas.pipeline.run as run
from deltas.model import base, downsample
import deltas.plotting.plots as plots
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Get data

# %%
N1 = 10000
N2 = 10
# Gaussian (not always seperable)
data_clf = run.get_data(
    m1=[-2, -2],
    m2=[2, 2],
    cov1=[[1, 0], [0, 1]],
    cov2=[[1, 0], [0, 1]],
    N1=N1,
    N2=N2,
    scale=False
    )

# %% [markdown]
# ## Get Classifier

# %%
model = 'SVM-linear'
model = 'SVM-rbf'
# model = 'Linear'
# model = 'MLP'

balance_clf = True
# balance_clf = False

data_clf['clf'], clf_SMOTE = run.get_classifier(
                      data_clf=data_clf,
                      model=model,
                      balance_clf=balance_clf)
# Out:
# clf
# SMOTE

# %% [markdown]
# ## Fit deltas

# %%
X = data_clf['data']['X']
y = data_clf['data']['y']
clf = data_clf['clf']
deltas_model = downsample.downsample_deltas(
    clf).fit(X, y, _print=True, _plot=True, max_trials=10000, grid_search=False)
# Out:
# Original Data
# Original dataset is solvable so not downsampling, set 'force_downsample' to 'True' to try and find a lower loss via downsampling anyway
# Original Data:

# %% [markdown]
# ## Plot training data information

# %%
deltas_model.plot_data(data_clf)

# %% [markdown]
# ## See how classifier's boudnary changes with delta

# %%
@ipywidgets.interact_manual(
    delta2=(0.00001, 1., 0.00001),
)
def plot(delta2=1):
    ax, _ = plots._get_axes(None)
    plots.plot_classes(data_clf['data'], ax=ax)
    def pred_func(X): return deltas_model._predict_given_delta2(X, delta2)
    plots.plot_decision_boundary_custom_pred(
        pred_func, data_clf['data'], ax=ax, probs=False)
    ax.set_title(f'delta_class0 = {delta2}')
    plots.plt.show()
# Out:
# interactive(children=(FloatSlider(value=1.0, description='delta2', max=1.0, min=1e-05, step=1e-05), Button(des…

# %% [markdown]
# ## Show parameters

# %%
deltas_model.print_params()
# Out:
# Parameters
#                 R:  2.126527199689603
#                 N1: 10000
#                 N2: 10
#                 R1: 0.38171167525359523
#                 R2: 0.3747967995238515
#                 M:  1.908212703675232
#                 D:  2.1672200378108033
#                 C1: 1
#                 C2: 1

# %% [markdown]
# # Evaluation on test data

# %%
mdels = {
    'original': clf,
    'deltas': deltas_model,
    'SMOTE': clf_SMOTE,
         }
run.eval_test(mdels,
                       data_clf['data_test'], _print=True, _plot=True)
# Out:
# original accuracy: 0.9517
# deltas accuracy: 0.98285
# SMOTE accuracy: 0.97335
#
# original F1: 0.9492487128296732
# deltas F1: 0.9825560697757209
# SMOTE F1: 0.9726231444861061
#
# original precision0: 0.9119095385737734
# deltas precision0: 0.9671084453903454
# SMOTE precision0: 0.9494824802962681
#
# original precision1: 1.0
# deltas precision1: 0.999689537410742
# SMOTE precision1: 0.999894392227268
# original
# deltas
# SMOTE
